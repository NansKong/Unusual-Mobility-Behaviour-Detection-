# %%
# !pip install pytorchvideo transformers evaluate torchvision==0.14
# Out:
# Collecting pytorchvideo
#   Downloading pytorchvideo-0.1.5.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting torchvision==0.14
#   Downloading torchvision-0.14.0-cp310-cp310-manylinux1_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14) (2.32.3)
# Collecting torch==1.13.0 (from torchvision==0.14)
#   Downloading torch-1.13.0-cp310-cp310-manylinux1_x86_64.whl.metadata (23 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14) (11.0.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==1.13.0->torchvision==0.14)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==1.13.0->torchvision==0.14)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==1.13.0->torchvision==0.14)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==1.13.0->torchvision==0.14)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision==0.14) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision==0.14) (0.45.1)
# Collecting fvcore (from pytorchvideo)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting av (from pytorchvideo)
#   Downloading av-14.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting parameterized (from pytorchvideo)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting iopath (from pytorchvideo)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pytorchvideo) (3.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.10.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14) (2024.8.30)
# Collecting yacs>=0.1.6 (from fvcore->pytorchvideo)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (2.5.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorchvideo) (0.9.0)
# Collecting portalocker (from iopath->pytorchvideo)
#   Downloading portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading torchvision-0.14.0-cp310-cp310-manylinux1_x86_64.whl (24.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 71.6 MB/s eta 0:00:00
# Downloading torch-1.13.0-cp310-cp310-manylinux1_x86_64.whl (890.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 82.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 54.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.3 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.2 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 35.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.0 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.8 MB/s eta 0:00:00
# Downloading av-14.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 50.3 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.8 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.0.0-py3-none-any.whl (19 kB)
# Building wheels for collected packages: pytorchvideo, fvcore, iopath
#   Building wheel for pytorchvideo (setup.py) ... done
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=188685 sha256=12c4ee65b1eb8d506a7894cec84693e3b88c842c7183b4783a234f84e2daed1e
#   Stored in directory: /root/.cache/pip/wheels/ff/4e/81/0f72a543be9ed7eb737c95bfc5da4025e73226b44368074ece
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61396 sha256=6e66709ca84e915cf57bbd20cfda61ebe627708822ebfdcec4467b03d9f2842f
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31528 sha256=665200198559ec0a193f78ab9f310942adc873a5e0c005fd1a2f8d236814093a
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built pytorchvideo fvcore iopath
# Installing collected packages: yacs, xxhash, portalocker, parameterized, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, fsspec, dill, av, nvidia-cudnn-cu11, multiprocess, iopath, torch, fvcore, torchvision, pytorchvideo, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 1.13.0 which is incompatible.
# Successfully installed av-14.0.1 datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 fvcore-0.1.5.post20221221 iopath-0.1.10 multiprocess-0.70.16 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 parameterized-0.9.0 portalocker-3.0.0 pytorchvideo-0.1.5 torch-1.13.0 torchvision-0.14.0 xxhash-3.5.0 yacs-0.1.8

# %%
import os
import warnings
import torch

# %%
base_path = "/content/drive/MyDrive/crime_data/"
train_file = os.path.join(base_path, "Action_Recognition_splits", "train_full.txt")
test_file = os.path.join(base_path, "Action_Recognition_splits", "test_full.txt")
class_file = os.path.join(base_path, "Action_Recognition_splits", "ClassIDs.txt")
temporal_annotations_file = os.path.join(base_path, "Temporal_Anomaly_Annotation_for_Testing_Videos.txt")

print("File Class exists:", os.path.exists(class_file))
print("File Train exists:", os.path.exists(train_file))
print("File Test exists:", os.path.exists(test_file))
print("File Temporal exists:", os.path.exists(temporal_annotations_file))
# Out:
# File Class exists: True
# File Train exists: True
# File Test exists: True
# File Temporal exists: True

# %%
# Load class mappings
def load_classes(class_file):
    with open(class_file, "r") as f:
        lines = f.read().strip().split("\n")
    # Normalize indices to start from 0
    return {line.split()[0]: int(line.split()[1]) - 1 for line in lines}

def reverse_mapping(class_mapping):
    """
    Create a reverse mapping from IDs to class names.

    Args:
        class_mapping (dict): Mapping of class names to IDs.

    Returns:
        dict: Mapping of IDs to class names.
    """
    return {v: k for k, v in class_mapping.items()}

class_mapping = load_classes(class_file)
reverse_mapping = reverse_mapping(class_mapping)
print(class_mapping)
print(reverse_mapping)
# Out:
# {'Abuse': 0, 'Arrest': 1, 'Arson': 2, 'Assault': 3, 'Burglary': 4, 'Explosion': 5, 'Fighting': 6, 'Normal_Videos_event': 7, 'RoadAccidents': 8, 'Robbery': 9, 'Shooting': 10, 'Shoplifting': 11, 'Stealing': 12, 'Vandalism': 13}
# {0: 'Abuse', 1: 'Arrest', 2: 'Arson', 3: 'Assault', 4: 'Burglary', 5: 'Explosion', 6: 'Fighting', 7: 'Normal_Videos_event', 8: 'RoadAccidents', 9: 'Robbery', 10: 'Shooting', 11: 'Shoplifting', 12: 'Stealing', 13: 'Vandalism'}

# %%
import random

# Match video paths with labels
def load_video_label_pairs(split_file, classes):
        video_label_pairs = []
        with open(split_file, "r") as f:
            lines = f.read().strip().split("\n")
        for line in lines:
            label, video_path = line.strip().split("/")
            full_path = os.path.join(base_path, "Anomaly_Videos", label + "/" + video_path.strip())
            if os.path.exists(full_path):
                video_label_pairs.append((full_path, {"label": classes[label]}))
            else:
                warnings.warn(f"File not found: {full_path}")
        print(f"Total video-label pairs loaded: {len(video_label_pairs)}")  # Debugging
        return video_label_pairs

def split_train_val(video_label_pairs, val_ratio=0.1, seed=None):
    """
    Split video-label pairs into train and val datasets.

    Args:
        video_label_pairs (list): List of video-label pairs.
        val_ratio (float): The ratio of data to be used for valuation.
        seed (int): Random seed for reproducibility.

    Returns:
        tuple: (train_video_label_pairs, val_video_label_pairs)
    """
    if seed is not None:
        random.seed(seed)  # Set the seed for reproducibility

    # Shuffle the dataset
    random.shuffle(video_label_pairs)

    # Calculate the split index
    val_size = int(len(video_label_pairs) * val_ratio)

    # Split the dataset
    val_video_label_pairs = video_label_pairs[:val_size]
    train_video_label_pairs = video_label_pairs[val_size:]

    return train_video_label_pairs, val_video_label_pairs

# Example usage
val_ratio = 0.1  # 10% for valuation
seed = 42         # Set a seed for reproducibility
train_video_label_pairs = load_video_label_pairs(train_file, class_mapping)

train_video_label_pairs, val_video_label_pairs = split_train_val(train_video_label_pairs, val_ratio, seed)
test_video_label_pairs = load_video_label_pairs(test_file, class_mapping)

# Output for verification
print(f"Total train video-label pairs: {len(train_video_label_pairs)}")
print(f"Total val video-label pairs: {len(val_video_label_pairs)}")
print("TRAIN LABEL/PATH: ", train_video_label_pairs[:10])
print("val LABEL/PATH: ", val_video_label_pairs[:10])
print("TEST LABEL/PATH: ",test_video_label_pairs[:10])
# Out:
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_317_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_345_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_352_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_360_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_365_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_401_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_417_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_439_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_452_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_453_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_478_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_576_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_597_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_603_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_606_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_621_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_634_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_641_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_656_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_696_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_704_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_722_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_745_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_758_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_781_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_798_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_801_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_828_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_831_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_877_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_881_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_885_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_892_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_905_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_912_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_913_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_914_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_929_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_015_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_050_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_100_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_129_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_150_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_246_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_247_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_248_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_251_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_289_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_310_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# <ipython-input-5-ebe9204fee77>:14: UserWarning: File not found: /content/drive/MyDrive/crime_data/Anomaly_Videos/Normal_Videos_event/Normal_Videos_312_x264.mp4
#   warnings.warn(f"File not found: {full_path}")
# Total video-label pairs loaded: 1976
# Total video-label pairs loaded: 624
# Total train video-label pairs: 1779
# Total val video-label pairs: 197
# TRAIN LABEL/PATH:  [('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse031_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Stealing/Stealing018_x264.mp4', {'label': 12}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Shoplifting/Shoplifting039_x264.mp4', {'label': 11}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Shooting/Shooting041_x264.mp4', {'label': 10}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Arrest/Arrest006_x264.mp4', {'label': 1}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/RoadAccidents/RoadAccidents042_x264.mp4', {'label': 8}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Stealing/Stealing059_x264.mp4', {'label': 12}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/RoadAccidents/RoadAccidents017_x264.mp4', {'label': 8}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Vandalism/Vandalism020_x264.mp4', {'label': 13}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Shooting/Shooting010_x264.mp4', {'label': 10})]
# val LABEL/PATH:  [('/content/drive/MyDrive/crime_data/Anomaly_Videos/Vandalism/Vandalism037_x264.mp4', {'label': 13}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Arson/Arson029_x264.mp4', {'label': 2}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Stealing/Stealing031_x264.mp4', {'label': 12}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse016_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Shooting/Shooting053_x264.mp4', {'label': 10}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Burglary/Burglary014_x264.mp4', {'label': 4}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Assault/Assault034_x264.mp4', {'label': 3}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Stealing/Stealing024_x264.mp4', {'label': 12}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Burglary/Burglary018_x264.mp4', {'label': 4}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Arson/Arson010_x264.mp4', {'label': 2})]
# TEST LABEL/PATH:  [('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse001_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse002_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse003_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse004_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse005_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse006_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse007_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse008_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse009_x264.mp4', {'label': 0}), ('/content/drive/MyDrive/crime_data/Anomaly_Videos/Abuse/Abuse010_x264.mp4', {'label': 0})]

# %%
from transformers import VideoMAEImageProcessor, VideoMAEForVideoClassification
model_ckpt = "MCG-NJU/videomae-large"
image_processor = VideoMAEImageProcessor.from_pretrained(model_ckpt)
model = VideoMAEForVideoClassification.from_pretrained(
    model_ckpt,
    label2id=class_mapping,
    id2label=reverse_mapping,
    ignore_mismatched_sizes=True,  # provide this in case you're planning to fine-tune an already fine-tuned checkpoint
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.37G [00:00<?, ?B/s]
# Some weights of VideoMAEForVideoClassification were not initialized from the model checkpoint at MCG-NJU/videomae-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from pytorchvideo.data import LabeledVideoDataset, make_clip_sampler
import pytorchvideo.data
from pytorchvideo.transforms import (
    ApplyTransformToKey,
    Normalize,
    RandomShortSideScale,
    RemoveKey,
    ShortSideScale,
    UniformTemporalSubsample,
)

from torchvision.transforms import (
    Compose,
    Lambda,
    CenterCrop,
    RandomHorizontalFlip,
    Resize,
)

# %%
mean = image_processor.image_mean
std = image_processor.image_std
if "shortest_edge" in image_processor.size:
    height = width = image_processor.size["shortest_edge"]
else:
    height = image_processor.size["height"]
    width = image_processor.size["width"]
resize_to = (height, width)

num_frames_to_sample = model.config.num_frames
sample_rate = 800
fps = 30
clip_duration = num_frames_to_sample * sample_rate / fps

# %%
train_transform = Compose(
    [
        ApplyTransformToKey(
            key="video",
            transform=Compose(
                [
                    UniformTemporalSubsample(num_frames_to_sample),
                    Lambda(lambda x: x / 255.0),
                    Normalize(mean, std),
                    RandomShortSideScale(min_size=256, max_size=320),
                    Resize(resize_to),
                    RandomHorizontalFlip(p=0.5),
                ]
            ),
        ),
    ]
)

val_transform = Compose([
    ApplyTransformToKey(
        key="video",
        transform=Compose([
            UniformTemporalSubsample(num_frames_to_sample),
            Lambda(lambda x: x / 255.0),
            Normalize(mean, std),
            Resize(resize_to),
        ]),
    ),
])

# %%
train_dataset = LabeledVideoDataset(
    labeled_video_paths=train_video_label_pairs,
    clip_sampler=make_clip_sampler("random", clip_duration),
    transform=train_transform,
    decode_audio=False,
)

test_dataset = LabeledVideoDataset(
    labeled_video_paths=test_video_label_pairs,
    clip_sampler=make_clip_sampler("uniform", clip_duration),
    transform=val_transform,
    decode_audio=False,
)

val_dataset = LabeledVideoDataset(
    labeled_video_paths=val_video_label_pairs,
    clip_sampler=make_clip_sampler("uniform", clip_duration),
    transform=val_transform,
    decode_audio=False,
)

# %%
import imageio
import numpy as np
from IPython.display import Image

def unnormalize_img(img):
    """Un-normalizes the image pixels."""
    img = (img * std) + mean
    img = (img * 255).astype("uint8")
    return img.clip(0, 255)

def create_gif(video_tensor, filename="sample.gif"):
    """Prepares a GIF from a video tensor.
...
    The video tensor is expected to have the following shape:
    (num_frames, num_channels, height, width).
    """
    frames = []
    for video_frame in video_tensor:
        frame_unnormalized = unnormalize_img(video_frame.permute(1, 2, 0).numpy())
        frames.append(frame_unnormalized)
    kargs = {"duration": 0.25}
    imageio.mimsave(filename, frames, "GIF", **kargs)
    return filename

def display_gif(video_tensor, video_class, gif_name="sample.gif"):
    """Prepares and displays a GIF from a video tensor."""
    video_tensor = video_tensor.permute(1, 0, 2, 3)
    gif_filename = create_gif(video_tensor, gif_name)
    print(f"Video Class: {reverse_mapping[video_class]}")
    return Image(filename=gif_filename)

sample_video = next(iter(train_dataset))
video_tensor = sample_video["video"]
video_label = sample_video["label"]
display_gif(video_tensor, video_label)
# Out:
# Video Class: Arrest

# %%
from transformers import TrainingArguments, Trainer


batch_size = 4
model_name = model_ckpt.split("/")[-1]
new_model_name = f"{model_name}-finetuned-UCF-Crime-dataset"
num_epochs = 30

args = TrainingArguments(
    new_model_name,
    gradient_accumulation_steps=2,
    remove_unused_columns=False,
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=5e-5,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    push_to_hub=False,
    num_train_epochs=num_epochs,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    fp16=True,
    max_steps=(train_dataset.num_videos // batch_size) * num_epochs,
)

# %%
import evaluate

metric = evaluate.load("accuracy")


def compute_metrics(eval_pred):
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
def collate_fn(examples):
    # permute to (num_frames, num_channels, height, width)
    pixel_values = torch.stack(
        [example["video"].permute(1, 0, 2, 3) for example in examples]
    )
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    processing_class=image_processor,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,

)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
# train_results = trainer.train()

# %%
# TESTING

# %%
from transformers import VideoMAEForVideoClassification, VideoMAEImageProcessor
import torch

# Load the model and processor from Hugging Face
model_name = "pabrcn/videomae-large-finetuned-UCF-Crime-dataset"
model = VideoMAEForVideoClassification.from_pretrained(model_name)
processor = VideoMAEImageProcessor.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/415 [00:00<?, ?B/s]

# %%
sample_video = next(iter(test_dataset))
video_tensor = sample_video["video"]
video_label = sample_video["label"]
display_gif(video_tensor, video_label)
# Out:
# Video Class: Arrest

# %%
# login to hugging face
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Load the model and processor
model_name = "pabrcn/videomae-large-finetuned-UCF-Crime-dataset"
device = "cuda" if torch.cuda.is_available() else "cpu"

# Reuse the already defined transforms, processor, and datasets
model = VideoMAEForVideoClassification.from_pretrained(
    model_name,
    label2id=class_mapping,
    id2label=reverse_mapping,
    ignore_mismatched_sizes=True,
).to(device)
# print(f"Input tensor shape: {video_tensor.shape}")
# print(model.config)
model.eval()

with torch.no_grad():
    for idx, sample in enumerate(test_dataset):
        video_tensor = sample["video"]  # Shape: [num_frames, num_channels, height, width]
        label = sample["label"]

        # Adjust tensor shape to match model's expectation
        video_tensor = video_tensor.permute(1, 0, 2, 3).unsqueeze(0).to(device)  # Shape: [batch_size, num_channels, num_frames, height, width]

        # Forward pass
        outputs = model(video_tensor)

        # Get predictions
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
        predicted_label = torch.argmax(probs, dim=-1).item()

        print(
            f"Video {idx}: Predicted label = {reverse_mapping[predicted_label]}, "
            f"True label = {reverse_mapping[label]}"
        )
# Out:
# Video 0: Predicted label = Stealing, True label = Stealing
# Video 1: Predicted label = Arson, True label = Arson
# Video 2: Predicted label = Assault, True label = Assault
# Video 3: Predicted label = Explosion, True label = Explosion
# Video 4: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 5: Predicted label = Vandalism, True label = Vandalism
# Video 6: Predicted label = Assault, True label = Assault
# Video 7: Predicted label = Arrest, True label = Arrest
# Video 8: Predicted label = Arrest, True label = Arrest
# Video 9: Predicted label = Arrest, True label = Arrest
# Video 10: Predicted label = Arrest, True label = Arrest
# Video 11: Predicted label = Burglary, True label = Burglary
# Video 12: Predicted label = Arson, True label = Arson
# Video 13: Predicted label = Vandalism, True label = Vandalism
# Video 14: Predicted label = Burglary, True label = Burglary
# Video 15: Predicted label = Stealing, True label = Stealing
# Video 16: Predicted label = Arrest, True label = Arrest
# Video 17: Predicted label = Burglary, True label = Burglary
# Video 18: Predicted label = Shooting, True label = Shooting
# Video 19: Predicted label = Shooting, True label = Shooting
# Video 20: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 21: Predicted label = Explosion, True label = Explosion
# Video 22: Predicted label = Arrest, True label = Arrest
# Video 23: Predicted label = Explosion, True label = Explosion
# Video 24: Predicted label = Explosion, True label = Explosion
# Video 25: Predicted label = Arson, True label = Arson
# Video 26: Predicted label = Shoplifting, True label = Shoplifting
# Video 27: Predicted label = Vandalism, True label = Vandalism
# Video 28: Predicted label = Shoplifting, True label = Shoplifting
# Video 29: Predicted label = Shoplifting, True label = Shoplifting
# Video 30: Predicted label = Burglary, True label = Burglary
# Video 31: Predicted label = Fighting, True label = Fighting
# Video 32: Predicted label = Arrest, True label = Arrest
# Video 33: Predicted label = Assault, True label = Assault
# Video 34: Predicted label = Vandalism, True label = Vandalism
# Video 35: Predicted label = Vandalism, True label = Vandalism
# Video 36: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 37: Predicted label = Burglary, True label = Burglary
# Video 38: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 39: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 40: Predicted label = Stealing, True label = Stealing
# Video 41: Predicted label = Abuse, True label = Abuse
# Video 42: Predicted label = Explosion, True label = Explosion
# Video 43: Predicted label = Robbery, True label = Robbery
# Video 44: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 45: Predicted label = Abuse, True label = Abuse
# Video 46: Predicted label = Arson, True label = Arson
# Video 47: Predicted label = Arrest, True label = Arrest
# Video 48: Predicted label = Arrest, True label = Arrest
# Video 49: Predicted label = Robbery, True label = Robbery
# Video 50: Predicted label = Abuse, True label = Abuse
# Video 51: Predicted label = Arson, True label = Arson
# Video 52: Predicted label = Robbery, True label = Robbery
# Video 53: Predicted label = Abuse, True label = Abuse
# Video 54: Predicted label = Abuse, True label = Abuse
# Video 55: Predicted label = Stealing, True label = Stealing
# Video 56: Predicted label = Fighting, True label = Fighting
# Video 57: Predicted label = Assault, True label = Assault
# Video 58: Predicted label = Shooting, True label = Shooting
# Video 59: Predicted label = Robbery, True label = Robbery
# Video 60: Predicted label = Vandalism, True label = Vandalism
# Video 61: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 62: Predicted label = Abuse, True label = Abuse
# Video 63: Predicted label = Arrest, True label = Arrest
# Video 64: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 65: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 66: Predicted label = Shooting, True label = Shooting
# Video 67: Predicted label = Burglary, True label = Burglary
# Video 68: Predicted label = Robbery, True label = Robbery
# Video 69: Predicted label = Robbery, True label = Robbery
# Video 70: Predicted label = Shooting, True label = Shooting
# Video 71: Predicted label = Stealing, True label = Stealing
# Video 72: Predicted label = Stealing, True label = Stealing
# Video 73: Predicted label = Shooting, True label = Shooting
# Video 74: Predicted label = Shooting, True label = Shooting
# Video 75: Predicted label = Vandalism, True label = Vandalism
# Video 76: Predicted label = Shoplifting, True label = Shoplifting
# Video 77: Predicted label = Vandalism, True label = Vandalism
# Video 78: Predicted label = Arrest, True label = Arrest
# Video 79: Predicted label = Shooting, True label = Shooting
# Video 80: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 81: Predicted label = Assault, True label = Assault
# Video 82: Predicted label = Vandalism, True label = Vandalism
# Video 83: Predicted label = Arrest, True label = Explosion
# Video 84: Predicted label = Fighting, True label = Fighting
# Video 85: Predicted label = RoadAccidents, True label = Arson
# Video 86: Predicted label = Vandalism, True label = Vandalism
# Video 87: Predicted label = Shooting, True label = Shooting
# Video 88: Predicted label = Arrest, True label = Shooting
# Video 89: Predicted label = Assault, True label = Assault
# Video 90: Predicted label = Arson, True label = Arson
# Video 91: Predicted label = Assault, True label = Arson
# Video 92: Predicted label = Shooting, True label = Shooting
# Video 93: Predicted label = Arrest, True label = Arrest
# Video 94: Predicted label = Arson, True label = Arson
# Video 95: Predicted label = Shoplifting, True label = Shoplifting
# Video 96: Predicted label = Abuse, True label = Abuse
# Video 97: Predicted label = Shoplifting, True label = Shoplifting
# Video 98: Predicted label = Explosion, True label = Explosion
# Video 99: Predicted label = Assault, True label = Assault
# Video 100: Predicted label = Arson, True label = Arson
# Video 101: Predicted label = Abuse, True label = Abuse
# Video 102: Predicted label = Burglary, True label = Burglary
# Video 103: Predicted label = Shooting, True label = Shoplifting
# Video 104: Predicted label = Fighting, True label = Fighting
# Video 105: Predicted label = Burglary, True label = Burglary
# Video 106: Predicted label = Assault, True label = Assault
# Video 107: Predicted label = Explosion, True label = Explosion
# Video 108: Predicted label = Abuse, True label = Abuse
# Video 109: Predicted label = Robbery, True label = Robbery
# Video 110: Predicted label = Abuse, True label = Abuse
# Video 111: Predicted label = Shoplifting, True label = Shoplifting
# Video 112: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 113: Predicted label = Shooting, True label = Shooting
# Video 114: Predicted label = Fighting, True label = Fighting
# Video 115: Predicted label = Vandalism, True label = Vandalism
# Video 116: Predicted label = Explosion, True label = Explosion
# Video 117: Predicted label = Arrest, True label = Burglary
# Video 118: Predicted label = Fighting, True label = Fighting
# Video 119: Predicted label = Abuse, True label = Abuse
# Video 120: Predicted label = Fighting, True label = Fighting
# Video 121: Predicted label = Abuse, True label = Abuse
# Video 122: Predicted label = Arrest, True label = Arrest
# Video 123: Predicted label = Shoplifting, True label = Shoplifting
# Video 124: Predicted label = Robbery, True label = Robbery
# Video 125: Predicted label = Robbery, True label = Robbery
# Video 126: Predicted label = Abuse, True label = Abuse
# Video 127: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 128: Predicted label = Abuse, True label = Arrest
# Video 129: Predicted label = Stealing, True label = Stealing
# Video 130: Predicted label = Vandalism, True label = Fighting
# Video 131: Predicted label = Stealing, True label = Stealing
# Video 132: Predicted label = Robbery, True label = Robbery
# Video 133: Predicted label = Assault, True label = Assault
# Video 134: Predicted label = Robbery, True label = Robbery
# Video 135: Predicted label = Explosion, True label = Explosion
# Video 136: Predicted label = Explosion, True label = Explosion
# Video 137: Predicted label = Stealing, True label = Stealing
# Video 138: Predicted label = Burglary, True label = Burglary
# Video 139: Predicted label = Arrest, True label = Arrest
# Video 140: Predicted label = Stealing, True label = Stealing
# Video 141: Predicted label = Shoplifting, True label = Shoplifting
# Video 142: Predicted label = Vandalism, True label = Vandalism
# Video 143: Predicted label = Shooting, True label = Shooting
# Video 144: Predicted label = Robbery, True label = Robbery
# Video 145: Predicted label = Robbery, True label = Robbery
# Video 146: Predicted label = Abuse, True label = Abuse
# Video 147: Predicted label = Assault, True label = Assault
# Video 148: Predicted label = Assault, True label = Assault
# Video 149: Predicted label = Vandalism, True label = Vandalism
# Video 150: Predicted label = Vandalism, True label = Vandalism
# Video 151: Predicted label = Vandalism, True label = Vandalism
# Video 152: Predicted label = Explosion, True label = Explosion
# Video 153: Predicted label = Robbery, True label = Robbery
# Video 154: Predicted label = Vandalism, True label = Vandalism
# Video 155: Predicted label = Assault, True label = Assault
# Video 156: Predicted label = Abuse, True label = Abuse
# Video 157: Predicted label = Arrest, True label = Arrest
# Video 158: Predicted label = Assault, True label = Assault
# Video 159: Predicted label = Vandalism, True label = Vandalism
# Video 160: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 161: Predicted label = Arrest, True label = Arrest
# Video 162: Predicted label = Assault, True label = Assault
# Video 163: Predicted label = Fighting, True label = Fighting
# Video 164: Predicted label = Fighting, True label = Fighting
# Video 165: Predicted label = RoadAccidents, True label = Robbery
# Video 166: Predicted label = Shoplifting, True label = Shoplifting
# Video 167: Predicted label = Burglary, True label = Burglary
# Video 168: Predicted label = Fighting, True label = Fighting
# Video 169: Predicted label = Arson, True label = Arson
# Video 170: Predicted label = Assault, True label = Assault
# Video 171: Predicted label = Abuse, True label = Abuse
# Video 172: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 173: Predicted label = Burglary, True label = Burglary
# Video 174: Predicted label = Arson, True label = Arson
# Video 175: Predicted label = Stealing, True label = Stealing
# Video 176: Predicted label = Robbery, True label = Robbery
# Video 177: Predicted label = Robbery, True label = Robbery
# Video 178: Predicted label = Stealing, True label = Stealing
# Video 179: Predicted label = Burglary, True label = Burglary
# Video 180: Predicted label = Burglary, True label = Burglary
# Video 181: Predicted label = Explosion, True label = Explosion
# Video 182: Predicted label = Shooting, True label = Shooting
# Video 183: Predicted label = Assault, True label = Assault
# Video 184: Predicted label = Stealing, True label = Stealing
# Video 185: Predicted label = Shoplifting, True label = Shoplifting
# Video 186: Predicted label = Arson, True label = Arson
# Video 187: Predicted label = Arrest, True label = Arrest
# Video 188: Predicted label = Fighting, True label = Fighting
# Video 189: Predicted label = Stealing, True label = Stealing
# Video 190: Predicted label = Abuse, True label = Abuse
# Video 191: Predicted label = RoadAccidents, True label = Shooting
# Video 192: Predicted label = Shoplifting, True label = Shoplifting
# Video 193: Predicted label = Arson, True label = Arson
# Video 194: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 195: Predicted label = Abuse, True label = Abuse
# Video 196: Predicted label = Fighting, True label = Fighting
# Video 197: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 198: Predicted label = Burglary, True label = Burglary
# Video 199: Predicted label = Stealing, True label = Stealing
# Video 200: Predicted label = Assault, True label = Assault
# Video 201: Predicted label = Assault, True label = Assault
# Video 202: Predicted label = Arrest, True label = Arrest
# Video 203: Predicted label = Fighting, True label = Fighting
# Video 204: Predicted label = Explosion, True label = Explosion
# Video 205: Predicted label = Burglary, True label = Burglary
# Video 206: Predicted label = Burglary, True label = Burglary
# Video 207: Predicted label = Arrest, True label = Arrest
# Video 208: Predicted label = Arrest, True label = Arrest
# Video 209: Predicted label = Abuse, True label = Abuse
# Video 210: Predicted label = Abuse, True label = Abuse
# Video 211: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 212: Predicted label = Vandalism, True label = Vandalism
# Video 213: Predicted label = Shooting, True label = Shooting
# Video 214: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 215: Predicted label = Assault, True label = Assault
# Video 216: Predicted label = Shooting, True label = Shooting
# Video 217: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 218: Predicted label = Burglary, True label = Burglary
# Video 219: Predicted label = Abuse, True label = Abuse
# Video 220: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 221: Predicted label = Abuse, True label = Abuse
# Video 222: Predicted label = Vandalism, True label = Vandalism
# Video 223: Predicted label = Shoplifting, True label = Shoplifting
# Video 224: Predicted label = Shooting, True label = Shooting
# Video 225: Predicted label = Explosion, True label = Explosion
# Video 226: Predicted label = Assault, True label = Assault
# Video 227: Predicted label = Abuse, True label = Abuse
# Video 228: Predicted label = Vandalism, True label = Vandalism
# Video 229: Predicted label = Shoplifting, True label = Shoplifting
# Video 230: Predicted label = Explosion, True label = Explosion
# Video 231: Predicted label = Stealing, True label = Stealing
# Video 232: Predicted label = Robbery, True label = Robbery
# Video 233: Predicted label = Explosion, True label = Explosion
# Video 234: Predicted label = Robbery, True label = Robbery
# Video 235: Predicted label = Robbery, True label = Robbery
# Video 236: Predicted label = Robbery, True label = Robbery
# Video 237: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 238: Predicted label = Burglary, True label = Burglary
# Video 239: Predicted label = Arson, True label = Arson
# Video 240: Predicted label = Stealing, True label = Stealing
# Video 241: Predicted label = Robbery, True label = Robbery
# Video 242: Predicted label = Abuse, True label = Abuse
# Video 243: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 244: Predicted label = Arson, True label = Arson
# Video 245: Predicted label = Vandalism, True label = Shooting
# Video 246: Predicted label = Robbery, True label = Robbery
# Video 247: Predicted label = Arrest, True label = Arrest
# Video 248: Predicted label = Arrest, True label = Arrest
# Video 249: Predicted label = Vandalism, True label = Vandalism
# Video 250: Predicted label = Abuse, True label = Abuse
# Video 251: Predicted label = Shoplifting, True label = Shoplifting
# Video 252: Predicted label = Arson, True label = Arson
# Video 253: Predicted label = Arson, True label = Arson
# Video 254: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 255: Predicted label = Fighting, True label = Fighting
# Video 256: Predicted label = Burglary, True label = Fighting
# Video 257: Predicted label = Explosion, True label = Explosion
# Video 258: Predicted label = Shoplifting, True label = Shoplifting
# Video 259: Predicted label = Vandalism, True label = Vandalism
# Video 260: Predicted label = RoadAccidents, True label = Stealing
# Video 261: Predicted label = Arrest, True label = Arrest
# Video 262: Predicted label = Arson, True label = Arson
# Video 263: Predicted label = Arson, True label = Arson
# Video 264: Predicted label = RoadAccidents, True label = Arson
# Video 265: Predicted label = Arson, True label = Arson
# Video 266: Predicted label = Vandalism, True label = Arson
# Video 267: Predicted label = Assault, True label = Arson
# Video 268: Predicted label = Vandalism, True label = Arson
# Video 269: Predicted label = Arson, True label = Arson
# Video 270: Predicted label = Vandalism, True label = Arson
# Video 271: Predicted label = Arrest, True label = Arrest
# Video 272: Predicted label = Arson, True label = Arson
# Video 273: Predicted label = Vandalism, True label = Vandalism
# Video 274: Predicted label = Arrest, True label = Arrest
# Video 275: Predicted label = Robbery, True label = Robbery
# Video 276: Predicted label = Arrest, True label = Arrest
# Video 277: Predicted label = Shooting, True label = Shooting
# Video 278: Predicted label = Stealing, True label = Stealing
# Video 279: Predicted label = Shooting, True label = Shooting
# Video 280: Predicted label = Robbery, True label = Robbery
# Video 281: Predicted label = Shoplifting, True label = Shoplifting
# Video 282: Predicted label = Arrest, True label = Arrest
# Video 283: Predicted label = Burglary, True label = Burglary
# Video 284: Predicted label = Vandalism, True label = Vandalism
# Video 285: Predicted label = Vandalism, True label = Vandalism
# Video 286: Predicted label = Robbery, True label = Robbery
# Video 287: Predicted label = Arson, True label = Arson
# Video 288: Predicted label = Shoplifting, True label = Shoplifting
# Video 289: Predicted label = Stealing, True label = Stealing
# Video 290: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 291: Predicted label = Stealing, True label = Stealing
# Video 292: Predicted label = Assault, True label = Assault
# Video 293: Predicted label = Vandalism, True label = Vandalism
# Video 294: Predicted label = Arson, True label = Arson
# Video 295: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 296: Predicted label = Arrest, True label = Arrest
# Video 297: Predicted label = Shooting, True label = Shooting
# Video 298: Predicted label = Shoplifting, True label = Shoplifting
# Video 299: Predicted label = Assault, True label = Assault
# Video 300: Predicted label = Assault, True label = Assault
# Video 301: Predicted label = Abuse, True label = Abuse
# Video 302: Predicted label = Arson, True label = Arson
# Video 303: Predicted label = Assault, True label = Assault
# Video 304: Predicted label = Explosion, True label = Explosion
# Video 305: Predicted label = Arrest, True label = Arrest
# Video 306: Predicted label = Robbery, True label = Robbery
# Video 307: Predicted label = Arrest, True label = Arrest
# Video 308: Predicted label = Fighting, True label = Fighting
# Video 309: Predicted label = Arson, True label = Arson
# Video 310: Predicted label = Arson, True label = Arson
# Video 311: Predicted label = Shoplifting, True label = Shoplifting
# Video 312: Predicted label = Fighting, True label = Fighting
# Video 313: Predicted label = Robbery, True label = Robbery
# Video 314: Predicted label = Explosion, True label = Explosion
# Video 315: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 316: Predicted label = Stealing, True label = Stealing
# Video 317: Predicted label = Explosion, True label = Explosion
# Video 318: Predicted label = Vandalism, True label = Vandalism
# Video 319: Predicted label = Vandalism, True label = Vandalism
# Video 320: Predicted label = Shoplifting, True label = Shoplifting
# Video 321: Predicted label = Fighting, True label = Fighting
# Video 322: Predicted label = Arson, True label = Arson
# Video 323: Predicted label = Fighting, True label = Fighting
# Video 324: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 325: Predicted label = Burglary, True label = Burglary
# Video 326: Predicted label = Shooting, True label = Shooting
# Video 327: Predicted label = Burglary, True label = Burglary
# Video 328: Predicted label = Stealing, True label = Stealing
# Video 329: Predicted label = Explosion, True label = Explosion
# Video 330: Predicted label = Arrest, True label = Arrest
# Video 331: Predicted label = Burglary, True label = Burglary
# Video 332: Predicted label = Burglary, True label = Burglary
# Video 333: Predicted label = Arrest, True label = Arrest
# Video 334: Predicted label = Arson, True label = Arson
# Video 335: Predicted label = Arson, True label = Arson
# Video 336: Predicted label = Burglary, True label = Burglary
# Video 337: Predicted label = Arson, True label = Arson
# Video 338: Predicted label = Shooting, True label = Shooting
# Video 339: Predicted label = Explosion, True label = Explosion
# Video 340: Predicted label = Arson, True label = Arson
# Video 341: Predicted label = Fighting, True label = Fighting
# Video 342: Predicted label = Shoplifting, True label = Shoplifting
# Video 343: Predicted label = Shoplifting, True label = Shoplifting
# Video 344: Predicted label = Shoplifting, True label = Shoplifting
# Video 345: Predicted label = Shoplifting, True label = Shoplifting
# Video 346: Predicted label = Shoplifting, True label = Shoplifting
# Video 347: Predicted label = Burglary, True label = Burglary
# Video 348: Predicted label = Arrest, True label = Arson
# Video 349: Predicted label = Arson, True label = Arson
# Video 350: Predicted label = Shooting, True label = Shooting
# Video 351: Predicted label = Stealing, True label = Stealing
# Video 352: Predicted label = Fighting, True label = Fighting
# Video 353: Predicted label = Vandalism, True label = Vandalism
# Video 354: Predicted label = Robbery, True label = Robbery
# Video 355: Predicted label = Vandalism, True label = Vandalism
# Video 356: Predicted label = Shoplifting, True label = Shoplifting
# Video 357: Predicted label = Arson, True label = Arson
# Video 358: Predicted label = Burglary, True label = Burglary
# Video 359: Predicted label = Robbery, True label = Robbery
# Video 360: Predicted label = Abuse, True label = Abuse
# Video 361: Predicted label = Fighting, True label = Fighting
# Video 362: Predicted label = Vandalism, True label = Vandalism
# Video 363: Predicted label = Arson, True label = Arson
# Video 364: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 365: Predicted label = Robbery, True label = Robbery
# Video 366: Predicted label = Arrest, True label = Arrest
# Video 367: Predicted label = Assault, True label = Fighting
# Video 368: Predicted label = Abuse, True label = Abuse
# Video 369: Predicted label = Shoplifting, True label = Shoplifting
# Video 370: Predicted label = Shoplifting, True label = Shoplifting
# Video 371: Predicted label = Arrest, True label = Arrest
# Video 372: Predicted label = Stealing, True label = Stealing
# Video 373: Predicted label = Assault, True label = Assault
# Video 374: Predicted label = Shooting, True label = Shooting
# Video 375: Predicted label = Abuse, True label = Abuse
# Video 376: Predicted label = Fighting, True label = Fighting
# Video 377: Predicted label = Explosion, True label = Explosion
# Video 378: Predicted label = Arson, True label = Arson
# Video 379: Predicted label = Assault, True label = Assault
# Video 380: Predicted label = Vandalism, True label = Vandalism
# Video 381: Predicted label = Vandalism, True label = Vandalism
# Video 382: Predicted label = Shoplifting, True label = Shoplifting
# Video 383: Predicted label = Abuse, True label = Abuse
# Video 384: Predicted label = Vandalism, True label = Vandalism
# Video 385: Predicted label = Shooting, True label = Shooting
# Video 386: Predicted label = Stealing, True label = Stealing
# Video 387: Predicted label = Vandalism, True label = Vandalism
# Video 388: Predicted label = Assault, True label = Assault
# Video 389: Predicted label = Explosion, True label = Explosion
# Video 390: Predicted label = Abuse, True label = Abuse
# Video 391: Predicted label = Explosion, True label = Explosion
# Video 392: Predicted label = Abuse, True label = Abuse
# Video 393: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 394: Predicted label = Burglary, True label = Burglary
# Video 395: Predicted label = Fighting, True label = Fighting
# Video 396: Predicted label = Shoplifting, True label = Shoplifting
# Video 397: Predicted label = Explosion, True label = Explosion
# Video 398: Predicted label = Fighting, True label = Fighting
# Video 399: Predicted label = Fighting, True label = Fighting
# Video 400: Predicted label = Assault, True label = Assault
# Video 401: Predicted label = Shoplifting, True label = Shoplifting
# Video 402: Predicted label = Assault, True label = Assault
# Video 403: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 404: Predicted label = Stealing, True label = Stealing
# Video 405: Predicted label = Assault, True label = Assault
# Video 406: Predicted label = Fighting, True label = Fighting
# Video 407: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 408: Predicted label = Arson, True label = Arson
# Video 409: Predicted label = Robbery, True label = Robbery
# Video 410: Predicted label = Shoplifting, True label = Shoplifting
# Video 411: Predicted label = Stealing, True label = Stealing
# Video 412: Predicted label = Abuse, True label = Abuse
# Video 413: Predicted label = Assault, True label = Assault
# Video 414: Predicted label = RoadAccidents, True label = Shoplifting
# Video 415: Predicted label = Abuse, True label = Abuse
# Video 416: Predicted label = Fighting, True label = Fighting
# Video 417: Predicted label = Burglary, True label = Burglary
# Video 418: Predicted label = Fighting, True label = Fighting
# Video 419: Predicted label = Explosion, True label = Explosion
# Video 420: Predicted label = Burglary, True label = Burglary
# Video 421: Predicted label = Stealing, True label = Stealing
# Video 422: Predicted label = Burglary, True label = Burglary
# Video 423: Predicted label = Assault, True label = Assault
# Video 424: Predicted label = Shooting, True label = Shooting
# Video 425: Predicted label = Burglary, True label = Burglary
# Video 426: Predicted label = Stealing, True label = Stealing
# Video 427: Predicted label = Shoplifting, True label = Shoplifting
# Video 428: Predicted label = Shooting, True label = Shooting
# Video 429: Predicted label = Arson, True label = Arson
# Video 430: Predicted label = Vandalism, True label = Vandalism
# Video 431: Predicted label = Stealing, True label = Stealing
# Video 432: Predicted label = Abuse, True label = Abuse
# Video 433: Predicted label = Assault, True label = Assault
# Video 434: Predicted label = Abuse, True label = Abuse
# Video 435: Predicted label = Robbery, True label = Robbery
# Video 436: Predicted label = Stealing, True label = Stealing
# Video 437: Predicted label = Robbery, True label = Robbery
# Video 438: Predicted label = Burglary, True label = Burglary
# Video 439: Predicted label = Assault, True label = Assault
# Video 440: Predicted label = Stealing, True label = Stealing
# Video 441: Predicted label = Shooting, True label = Shooting
# Video 442: Predicted label = Shooting, True label = Shooting
# Video 443: Predicted label = Arrest, True label = Arrest
# Video 444: Predicted label = RoadAccidents, True label = Fighting
# Video 445: Predicted label = Fighting, True label = Fighting
# Video 446: Predicted label = Arrest, True label = Arrest
# Video 447: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 448: Predicted label = Arson, True label = Arson
# Video 449: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 450: Predicted label = Stealing, True label = Stealing
# Video 451: Predicted label = Burglary, True label = Burglary
# Video 452: Predicted label = Shoplifting, True label = Shoplifting
# Video 453: Predicted label = Stealing, True label = Stealing
# Video 454: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 455: Predicted label = Vandalism, True label = Vandalism
# Video 456: Predicted label = Stealing, True label = Stealing
# Video 457: Predicted label = Shooting, True label = Shooting
# Video 458: Predicted label = Explosion, True label = Explosion
# Video 459: Predicted label = Explosion, True label = Explosion
# Video 460: Predicted label = Assault, True label = Assault
# Video 461: Predicted label = Stealing, True label = Stealing
# Video 462: Predicted label = Shooting, True label = Shooting
# Video 463: Predicted label = Assault, True label = Assault
# Video 464: Predicted label = Arson, True label = Arson
# Video 465: Predicted label = Arrest, True label = Arrest
# Video 466: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 467: Predicted label = Vandalism, True label = Vandalism
# Video 468: Predicted label = Assault, True label = Assault
# Video 469: Predicted label = Assault, True label = Assault
# Video 470: Predicted label = Vandalism, True label = Vandalism
# Video 471: Predicted label = Robbery, True label = Robbery
# Video 472: Predicted label = Abuse, True label = Abuse
# Video 473: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 474: Predicted label = Shoplifting, True label = Shoplifting
# Video 475: Predicted label = Robbery, True label = Robbery
# Video 476: Predicted label = Stealing, True label = Stealing
# Video 477: Predicted label = Fighting, True label = Fighting
# Video 478: Predicted label = Vandalism, True label = Vandalism
# Video 479: Predicted label = Fighting, True label = Fighting
# Video 480: Predicted label = Shooting, True label = Shooting
# Video 481: Predicted label = Shoplifting, True label = Shoplifting
# Video 482: Predicted label = Robbery, True label = Robbery
# Video 483: Predicted label = Explosion, True label = Explosion
# Video 484: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 485: Predicted label = Fighting, True label = Fighting
# Video 486: Predicted label = Burglary, True label = Burglary
# Video 487: Predicted label = RoadAccidents, True label = Fighting
# Video 488: Predicted label = Shoplifting, True label = Shoplifting
# Video 489: Predicted label = Abuse, True label = Abuse
# Video 490: Predicted label = Robbery, True label = Robbery
# Video 491: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 492: Predicted label = Fighting, True label = Fighting
# Video 493: Predicted label = Vandalism, True label = Vandalism
# Video 494: Predicted label = Shoplifting, True label = Shoplifting
# Video 495: Predicted label = Shooting, True label = Shooting
# Video 496: Predicted label = Fighting, True label = Fighting
# Video 497: Predicted label = Robbery, True label = Robbery
# Video 498: Predicted label = Stealing, True label = Stealing
# Video 499: Predicted label = Vandalism, True label = Vandalism
# Video 500: Predicted label = Arrest, True label = Arrest
# Video 501: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 502: Predicted label = Vandalism, True label = Vandalism
# Video 503: Predicted label = Arson, True label = Arson
# Video 504: Predicted label = Arrest, True label = Arrest
# Video 505: Predicted label = Stealing, True label = Stealing
# Video 506: Predicted label = Assault, True label = Assault
# Video 507: Predicted label = Explosion, True label = Explosion
# Video 508: Predicted label = Robbery, True label = Robbery
# Video 509: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 510: Predicted label = Shoplifting, True label = Shoplifting
# Video 511: Predicted label = Explosion, True label = Explosion
# Video 512: Predicted label = Arrest, True label = Arrest
# Video 513: Predicted label = Shoplifting, True label = Shoplifting
# Video 514: Predicted label = Arson, True label = Stealing
# Video 515: Predicted label = Vandalism, True label = Vandalism
# Video 516: Predicted label = Fighting, True label = Fighting
# Video 517: Predicted label = Fighting, True label = Fighting
# Video 518: Predicted label = Robbery, True label = Robbery
# Video 519: Predicted label = Arrest, True label = Arrest
# Video 520: Predicted label = Burglary, True label = Burglary
# Video 521: Predicted label = Arrest, True label = Arrest
# Video 522: Predicted label = Vandalism, True label = Explosion
# Video 523: Predicted label = Explosion, True label = Explosion
# Video 524: Predicted label = Explosion, True label = Explosion
# Video 525: Predicted label = Explosion, True label = Explosion
# Video 526: Predicted label = Explosion, True label = Explosion
# Video 527: Predicted label = Explosion, True label = Explosion
# Video 528: Predicted label = Explosion, True label = Explosion
# Video 529: Predicted label = Explosion, True label = Explosion
# Video 530: Predicted label = Explosion, True label = Explosion
# Video 531: Predicted label = Explosion, True label = Explosion
# Video 532: Predicted label = Explosion, True label = Explosion
# Video 533: Predicted label = Shooting, True label = Shooting
# Video 534: Predicted label = Robbery, True label = Robbery
# Video 535: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 536: Predicted label = Shooting, True label = Shooting
# Video 537: Predicted label = Shooting, True label = Shooting
# Video 538: Predicted label = Shoplifting, True label = Shoplifting
# Video 539: Predicted label = Burglary, True label = Burglary
# Video 540: Predicted label = Assault, True label = Assault
# Video 541: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 542: Predicted label = Arrest, True label = Arrest
# Video 543: Predicted label = Robbery, True label = Robbery
# Video 544: Predicted label = Arrest, True label = Arrest
# Video 545: Predicted label = Stealing, True label = Stealing
# Video 546: Predicted label = Shooting, True label = Shooting
# Video 547: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 548: Predicted label = Assault, True label = Assault
# Video 549: Predicted label = Arson, True label = Arson
# Video 550: Predicted label = Stealing, True label = Stealing
# Video 551: Predicted label = Arrest, True label = Arrest
# Video 552: Predicted label = Fighting, True label = Fighting
# Video 553: Predicted label = Explosion, True label = Explosion
# Video 554: Predicted label = Abuse, True label = Abuse
# Video 555: Predicted label = Fighting, True label = Fighting
# Video 556: Predicted label = Arrest, True label = Arrest
# Video 557: Predicted label = Explosion, True label = Explosion
# Video 558: Predicted label = Assault, True label = Assault
# Video 559: Predicted label = Abuse, True label = Abuse
# Video 560: Predicted label = Abuse, True label = Abuse
# Video 561: Predicted label = Shoplifting, True label = Shoplifting
# Video 562: Predicted label = Fighting, True label = Fighting
# Video 563: Predicted label = Explosion, True label = Explosion
# Video 564: Predicted label = Shooting, True label = Shooting
# Video 565: Predicted label = Arson, True label = Arson
# Video 566: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 567: Predicted label = Explosion, True label = Explosion
# Video 568: Predicted label = Burglary, True label = Burglary
# Video 569: Predicted label = Vandalism, True label = Vandalism
# Video 570: Predicted label = Vandalism, True label = Vandalism
# Video 571: Predicted label = Explosion, True label = Explosion
# Video 572: Predicted label = Vandalism, True label = Vandalism
# Video 573: Predicted label = Stealing, True label = Stealing
# Video 574: Predicted label = Robbery, True label = Robbery
# Video 575: Predicted label = Fighting, True label = Fighting
# Video 576: Predicted label = Burglary, True label = Burglary
# Video 577: Predicted label = Robbery, True label = Robbery
# Video 578: Predicted label = Shoplifting, True label = Shoplifting
# Video 579: Predicted label = Explosion, True label = Explosion
# Video 580: Predicted label = Abuse, True label = Abuse
# Video 581: Predicted label = Arson, True label = Arson
# Video 582: Predicted label = Explosion, True label = Explosion
# Video 583: Predicted label = Shoplifting, True label = Shoplifting
# Video 584: Predicted label = RoadAccidents, True label = Abuse
# Video 585: Predicted label = Burglary, True label = Burglary
# Video 586: Predicted label = Fighting, True label = Fighting
# Video 587: Predicted label = Robbery, True label = Robbery
# Video 588: Predicted label = Fighting, True label = Fighting
# Video 589: Predicted label = Abuse, True label = Abuse
# Video 590: Predicted label = Abuse, True label = Abuse
# Video 591: Predicted label = Vandalism, True label = Vandalism
# Video 592: Predicted label = Shoplifting, True label = Shoplifting
# Video 593: Predicted label = Arson, True label = Arson
# Video 594: Predicted label = Assault, True label = Assault
# Video 595: Predicted label = Stealing, True label = Stealing
# Video 596: Predicted label = Explosion, True label = Explosion
# Video 597: Predicted label = Shoplifting, True label = Shoplifting
# Video 598: Predicted label = Shoplifting, True label = Shoplifting
# Video 599: Predicted label = Shooting, True label = Shooting
# Video 600: Predicted label = RoadAccidents, True label = Arrest
# Video 601: Predicted label = Assault, True label = Assault
# Video 602: Predicted label = Shooting, True label = Shooting
# Video 603: Predicted label = Fighting, True label = Fighting
# Video 604: Predicted label = Abuse, True label = Abuse
# Video 605: Predicted label = Burglary, True label = Burglary
# Video 606: Predicted label = Explosion, True label = Explosion
# Video 607: Predicted label = RoadAccidents, True label = Arrest
# Video 608: Predicted label = Shooting, True label = Shooting
# Video 609: Predicted label = Arson, True label = Arson
# Video 610: Predicted label = Shooting, True label = Shooting
# Video 611: Predicted label = Burglary, True label = Burglary
# Video 612: Predicted label = Abuse, True label = Abuse
# Video 613: Predicted label = Explosion, True label = Explosion
# Video 614: Predicted label = Shoplifting, True label = Shoplifting
# Video 615: Predicted label = Burglary, True label = Burglary
# Video 616: Predicted label = Shooting, True label = Shooting
# Video 617: Predicted label = Burglary, True label = Burglary
# Video 618: Predicted label = Abuse, True label = Abuse
# Video 619: Predicted label = Arrest, True label = Arrest
# Video 620: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 621: Predicted label = Stealing, True label = Stealing
# Video 622: Predicted label = Assault, True label = Assault
# Video 623: Predicted label = Shoplifting, True label = Shoplifting
# Video 624: Predicted label = Stealing, True label = Stealing
# Video 625: Predicted label = Assault, True label = Assault
# Video 626: Predicted label = Vandalism, True label = Arson
# Video 627: Predicted label = Assault, True label = Assault
# Video 628: Predicted label = Robbery, True label = Robbery
# Video 629: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 630: Predicted label = Burglary, True label = Burglary
# Video 631: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 632: Predicted label = Shooting, True label = Shooting
# Video 633: Predicted label = Burglary, True label = Burglary
# Video 634: Predicted label = Explosion, True label = Explosion
# Video 635: Predicted label = Robbery, True label = Robbery
# Video 636: Predicted label = Stealing, True label = Stealing
# Video 637: Predicted label = Assault, True label = Assault
# Video 638: Predicted label = RoadAccidents, True label = RoadAccidents
# Video 639: Predicted label = Shooting, True label = Shooting
# Video 640: Predicted label = Shooting, True label = Shooting
# Video 641: Predicted label = Abuse, True label = Abuse
# Video 642: Predicted label = Burglary, True label = Burglary
# Video 643: Predicted label = Arson, True label = Arson
# Video 644: Predicted label = Explosion, True label = Explosion
# Video 645: Predicted label = Explosion, True label = Explosion
# Video 646: Predicted label = Fighting, True label = Fighting
# Video 647: Predicted label = Explosion, True label = Explosion
# Video 648: Predicted label = Shoplifting, True label = Shoplifting
# Video 649: Predicted label = Burglary, True label = Burglary
# Video 650: Predicted label = Arson, True label = Arson
# Video 651: Predicted label = Arrest, True label = Arrest
